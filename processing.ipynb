# %%
import pandas as pd
import numpy as np

# %%
df_users = pd.read_json("users.json")
df_repos = pd.read_json("repository_data.json")
df_users.head(3)
# Out:
#        login      name                 company  \
# 0  yyx990803  Evan You                    None
# 1   halfrost  halfrost           KUBEFLOW CNCF
# 2     DIYgod    DIYgod  NATURAL SELECTION LABS
#
#                          location           email  hireable  \
# 0                       Singapore            None       NaN
# 1  [California, Singapore, China]  i@halfrost.com       NaN
# 2                       Singapore     i@diygod.me       NaN
#
#                                                  bio  public_repos  followers  \
# 0  Husband, father of two, independent OSS dev. @...           195     101745
# 1  CS master @Stanford 💪 天道酬勤，勤能补拙。博观而约取，厚积而薄发。Go...            32      17034
# 2                                    写代码是热爱，写到世界充满爱！            86      14141
#
#    following                created_at
# 0         96 2010-11-28 01:05:40+00:00
# 1        361 2015-02-03 07:01:48+00:00
# 2        443 2014-07-25 09:27:56+00:00

# %%
df_repos.head(3)
# Out:
#        login             full_name                created_at  \
# 0  yyx990803         vuejs/vuefire 2016-01-07 22:57:53+00:00
# 1  yyx990803          vuejs/router 2019-02-07 18:09:43+00:00
# 2  yyx990803  fastify/fastify-vite 2021-03-06 13:34:37+00:00
#
#    stargazers_count  watchers_count    language  has_projects  has_wiki  \
# 0              3858            3858  TypeScript          True      True
# 1              3914            3914  TypeScript          True      True
# 2               882             882  JavaScript          True      True
#
#   license_name
# 0          mit
# 1          mit
# 2          mit

# %%
df_users.sort_values('followers', ascending=False)[:5]
# Out:
#        login            name                 company  \
# 0  yyx990803        Evan You                    None
# 1   halfrost        halfrost           KUBEFLOW CNCF
# 2     DIYgod          DIYgod  NATURAL SELECTION LABS
# 3   yangshun    Yangshun Tay           GREATFRONTEND
# 4  bytedance  Bytedance Inc.                    None
#
#                          location                    email  hireable  \
# 0                       Singapore                     None       NaN
# 1  [California, Singapore, China]           i@halfrost.com       NaN
# 2                       Singapore              i@diygod.me       NaN
# 3                       Singapore  tay.yang.shun@gmail.com       NaN
# 4                       Singapore                     None       NaN
#
#                                                  bio  public_repos  followers  \
# 0  Husband, father of two, independent OSS dev. @...           195     101745
# ...

# %%
df_users.sort_values('created_at', ascending=True)[:5]
# Out:
#          login             name                  company   location  \
# 502    chuyeow   Cheah Chu Yeow                 WEGO.COM  Singapore
# 377  choonkeat  Chew Choon Keat                     None  Singapore
# 347    winston          Winston                     None  Singapore
# 26     cheeaun         Chee Aun  UNEMPLOYED SINCE JUL'22  Singapore
# 467       nowa         Nowa Zhu                     None  Singapore
#
#                          email  hireable  \
# 502          chuyeow@gmail.com       1.0
# 377        choonkeat@gmail.com       1.0
# 347  winston.yongwei@gmail.com       NaN
# 26           cheeaun@gmail.com       1.0
# 467          nowazhu@gmail.com       NaN
#
#                                                    bio  public_repos  \
# 502                                               None            73
# 377                                               None           145
# 347                                               None            39
# ...

# %%
df_repos.license_name.value_counts()[:3]
# Out:
# license_name
# mit           14245
# apache-2.0     6023
# other          4350
# Name: count, dtype: int64

# %%
df_users.company.value_counts()
# Out:
# company
# NATIONAL UNIVERSITY OF SINGAPORE    41
# NANYANG TECHNOLOGICAL UNIVERSITY    24
# TIKTOK                               9
# SHOPEE                               8
# GOOGLE                               6
#                                     ..
# NUMEN CYBER TECHNOLOGY               1
# TASKADE                              1
# HARBIN INSTITUTE OF TECHNOLOGY       1
# NUS, TENCENT                         1
# OPEN-RMF                             1
# Name: count, Length: 284, dtype: int64

# %%
df_repos.language.value_counts()
# Out:
# language
# JavaScript    8216
# Python        6789
# TypeScript    2968
# Java          2726
# Go            2338
#               ...
# Mercury          1
# CLIPS            1
# ABAP             1
# Rascal           1
# Stata            1
# Name: count, Length: 205, dtype: int64

# %%
users_after_2020 = df_users[df_users.created_at.dt.year > 2020].login

# %%
df_repos[df_repos.login.isin(users_after_2020)]['language'].value_counts()
# Out:
# language
# TypeScript          419
# JavaScript          216
# Python              196
# Rust                118
# Go                  102
# Solidity             57
# Java                 41
# HTML                 39
# Jupyter Notebook     30
# C++                  30
# Swift                24
# Dart                 22
# Shell                18
# Vue                  15
# CSS                  14
# Kotlin               14
# Markdown             12
# Move                 11
# MDX                   9
# Cairo                 7
# Dockerfile            7
# C                     5
# Lua                   4
# Astro                 4
# Objective-C           4
# C#                    4
# PHP                   3
# TeX                   3
# SCSS                  3
# Less                  2
# Sway                  2
# EJS                   2
# Ruby                  2
# HCL                   2
# MQL5                  1
# Smarty                1
# PowerShell            1
# WebAssembly           1
# ...

# %%
df_repos.groupby('language').agg({'stargazers_count': 'mean'}).sort_values('stargazers_count', ascending=False)
# Out:
#                      stargazers_count
# language
# Inno Setup                1506.000000
# MDX                       1193.048780
# Clojure                   1053.774194
# Gnuplot                    750.000000
# Vala                       741.500000
# ...                               ...
# HyPhy                        0.000000
# PureBasic                    0.000000
# Gleam                        0.000000
# Game Maker Language          0.000000
# jq                           0.000000
#
# [205 rows x 1 columns]

# %%
def leader_strength(row):
    return row['followers'] / (1 + row['following'])

# %%
df_users['leader_strength'] = df_users.apply(leader_strength, axis=1)

# %%
df_users.sort_values('leader_strength', ascending=False)[:5]
# Out:
#          login               name        company  \
# 4    bytedance     Bytedance Inc.           None
# 5     Jinjiang           Jinjiang  VUEJS TEAMBIT
# 7   cloudflare         Cloudflare           None
# 13     JamesNK  James Newton-King      MICROSOFT
# 15  Shib-Chain          ShibChain           None
#
#                                             location                email  \
# 4                                          Singapore                 None
# 5                                          Singapore  zhaojinjiang@me.com
# 7   San Francisco, London, Austin, Lisbon, Singapore                 None
# 13                                         Singapore                 None
# 15                                         Singapore    dev@shibchain.app
#
#     hireable                                                bio  public_repos  \
# 4        NaN                                               None           292
# ...
